# %%
import pandas as pd
import os

cwd = os.getcwd()
data_labels = f'{cwd}/data_labels.xlsx'
df = pd.read_excel(data_labels, nrows=42)
print(df)
# Out:
#     patient_n condition gender  mean_fd_before  mean_fd_after  \
# 0           1         E      M        0.064042       0.080243
# 1           2         E      M        0.137716       0.127427
# 2           3         E      F        0.084215       0.084362
# 3           4         P      M        0.119855       0.092257
# 4           6         E      M        0.289234       0.214378
# 5           7         P      M        0.113872       0.197664
# 6           8         P      M        0.144399       0.153126
# 7          10         E      M        0.066461       0.072340
# 8          11         P      M        0.116099       0.098267
# 9          12         P      F        0.086670       0.115023
# 10         13         P      M        0.189721       0.153698
# 11         14         E      M        0.089844       0.078786
# 12         16         E      F        0.080255       0.083810
# 13         18         E      M        0.135319       0.095447
# ...
