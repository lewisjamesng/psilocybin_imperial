# %%
import os
from nilearn import datasets, plotting
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from utils import project_root

root = project_root()

atlas = datasets.fetch_atlas_aal()
atlas_filename = atlas['maps']
plotting.plot_roi(atlas_filename)
plt.savefig(os.path.join(root, 'images/atlases', 'aal.png'))

atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, resolution_mm=2, yeo_networks=7)
atlas_filename = atlas['maps']
plotting.plot_roi(atlas_filename)
plt.savefig(os.path.join(root, 'images/atlases', 'schaefer.png'))

atlas_filename = os.path.join(root, 'ica_100/melodic_IC_sum.nii.gz')
plotting.plot_prob_atlas(atlas_filename)
plt.savefig(os.path.join(root, 'images/atlases', 'ica.png'))
